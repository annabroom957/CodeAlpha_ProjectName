# %% [markdown]
# <a href="https://colab.research.google.com/github/annabroom957/CodeAlpha_ProjectName/blob/main/Python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def get_random_word(word_list):
    return random.choice(word_list)

def display_word(word, guessed_letters):
    display = ''
    for letter in word:
        if letter in guessed_letters:
            display += letter + ' '
        else:
            display += '_ '
    return display.strip()

def is_word_guessed(word, guessed_letters):
    for letter in word:
        if letter not in guessed_letters:
            return False
    return True

def play_hangman():
    word_list = ['apple', 'mango', 'Grapes', 'heart', 'Retire']
    word = get_random_word(word_list)
    guessed_letters = []
    attempts = 6
    wrong_guesses = 0

    print("Welcome to Hangman!")
    print("Guess the word one letter at a time.")
    print(f"You have {attempts} incorrect guesses allowed.\n")

    while wrong_guesses < attempts:
        print(display_word(word, guessed_letters))
        guess = input("Enter a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single letter.\n")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter. Try again.\n")
            continue

        guessed_letters.append(guess)

        if guess in word:
            print(f"Good guess! {guess} is in the word.\n")
        else:
            wrong_guesses += 1
            print(f"Sorry, {guess} is not in the word.")
            print(f"Incorrect guesses left: {attempts - wrong_guesses}\n")

        if is_word_guessed(word, guessed_letters):
            print(f"Congratulations! You've guessed the word: {word}")
            break
    else:
        print(f"You've run out of guesses. The word was: {word}")

if __name__ == "__main__":
    play_hangman()
# Out:
# Welcome to Hangman!
# Guess the word one letter at a time.
# You have 6 incorrect guesses allowed.
#
# _ _ _ _
# Enter a letter: p
# Sorry, p is not in the word.
# Incorrect guesses left: 5
#
# _ _ _ _
# Enter a letter: P
# You already guessed that letter. Try again.
#
# _ _ _ _
# Enter a letter: y
# Sorry, y is not in the word.
# Incorrect guesses left: 4
#
# _ _ _ _
# Enter a letter: Y
# You already guessed that letter. Try again.
#
# _ _ _ _
# Enter a letter: T
# Sorry, t is not in the word.
# Incorrect guesses left: 3
#
# _ _ _ _
# Enter a letter: t
# You already guessed that letter. Try again.
#
# _ _ _ _
# Enter a letter: h
# Sorry, h is not in the word.
# Incorrect guesses left: 2
#
# _ _ _ _
# Enter a letter: H
# You already guessed that letter. Try again.
#
# _ _ _ _
# Enter a letter: o
# Sorry, o is not in the word.
# Incorrect guesses left: 1
#
# _ _ _ _
# Enter a letter: O
# You already guessed that letter. Try again.
#
# _ _ _ _
# Enter a letter: N
# ...
